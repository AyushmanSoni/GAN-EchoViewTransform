# %%
# prompt: connect the drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from math import log10, sqrt
import cv2
import numpy as np
import os

def PSNR(original, compressed):
    mse = np.mean((original - compressed) ** 2)
    if mse == 0:  # No error means infinite PSNR; we return 100 dB as a placeholder.
        return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr

if __name__ == "__main__":
    # Directories where your images are saved
    real_dir = '/content/drive/MyDrive/eval/actual'
    fake_dir = '/content/drive/MyDrive/eval/fake'

    psnr_values = []  # List to store PSNR values

    # Loop over patient IDs 400 to 450 (inclusive)
    for patient in range(400, 451):
        # Construct file paths using zero-padded numbering
        real_filename = f"patient{patient:04d}_actual.png"
        fake_filename = f"patient{patient:04d}_fake.png"
        real_path = os.path.join(real_dir, real_filename)
        fake_path = os.path.join(fake_dir, fake_filename)

        # Read images
        original = cv2.imread(real_path)
        compressed = cv2.imread(fake_path, 1)  # Color image

        # Check if images were loaded successfully
        if original is None or compressed is None:
            print(f"Warning: Could not load images for patient {patient}. Skipping this pair.")
            continue

        # If image sizes do not match, resize the compressed image to match the original
        if original.shape != compressed.shape:
            # cv2.resize expects size as (width, height)
            compressed = cv2.resize(compressed, (original.shape[1], original.shape[0]))

        # Compute PSNR for this pair
        psnr_value = PSNR(original, compressed)
        print(f"Patient {patient}: PSNR value is {psnr_value:.2f} dB")
        psnr_values.append(psnr_value)

    # Compute and print the average PSNR if any valid pairs were found
    if psnr_values:
        avg_psnr = np.mean(psnr_values)
        print(f"\nAverage PSNR over all valid image pairs: {avg_psnr:.2f} dB")
    else:
        print("No valid image pairs found.")
# Out:
# Patient 400: PSNR value is 30.84 dB
# Patient 401: PSNR value is 30.69 dB
# Patient 402: PSNR value is 30.73 dB
# Patient 403: PSNR value is 30.95 dB
# Patient 404: PSNR value is 30.78 dB
# Patient 405: PSNR value is 30.85 dB
# Patient 406: PSNR value is 31.06 dB
# Patient 407: PSNR value is 30.88 dB
# Patient 408: PSNR value is 30.89 dB
# Patient 409: PSNR value is 30.77 dB
# Patient 410: PSNR value is 30.90 dB
# Patient 411: PSNR value is 30.62 dB
# Patient 412: PSNR value is 30.96 dB
# Patient 413: PSNR value is 30.92 dB
# Patient 414: PSNR value is 30.83 dB
# Patient 415: PSNR value is 30.74 dB
# Patient 416: PSNR value is 30.78 dB
# Patient 417: PSNR value is 30.91 dB
# Patient 418: PSNR value is 30.70 dB
# Patient 419: PSNR value is 31.10 dB
# Patient 420: PSNR value is 31.12 dB
# Patient 421: PSNR value is 30.84 dB
# Patient 422: PSNR value is 30.82 dB
# Patient 423: PSNR value is 30.56 dB
# Patient 424: PSNR value is 30.68 dB
# Patient 425: PSNR value is 30.92 dB
# Patient 426: PSNR value is 30.88 dB
# Patient 427: PSNR value is 30.92 dB
# Patient 428: PSNR value is 30.72 dB
# Patient 429: PSNR value is 30.64 dB
# Patient 430: PSNR value is 30.83 dB
# Patient 431: PSNR value is 30.80 dB
# Patient 432: PSNR value is 31.25 dB
# Patient 433: PSNR value is 31.09 dB
# Patient 434: PSNR value is 30.84 dB
# Patient 435: PSNR value is 30.63 dB
# Patient 436: PSNR value is 30.96 dB
# Patient 437: PSNR value is 30.75 dB
# Patient 438: PSNR value is 30.88 dB
# Patient 439: PSNR value is 30.87 dB
# Patient 440: PSNR value is 30.87 dB
# Patient 441: PSNR value is 30.88 dB
# Patient 442: PSNR value is 30.91 dB
# Patient 443: PSNR value is 30.58 dB
# Patient 444: PSNR value is 30.83 dB
# Patient 445: PSNR value is 30.12 dB
# Patient 446: PSNR value is 30.58 dB
# Patient 447: PSNR value is 31.01 dB
# Patient 448: PSNR value is 30.81 dB
# Patient 449: PSNR value is 31.15 dB
# Patient 450: PSNR value is 30.80 dB
#
# Average PSNR over all valid image pairs: 30.83 dB

# %%
from skimage.metrics import structural_similarity as ssim
import cv2
import numpy as np
import os

def calculate_SSIM(original, compressed):
    # Convert images to grayscale if they are color images
    if len(original.shape) == 3:
        original_gray = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
        compressed_gray = cv2.cvtColor(compressed, cv2.COLOR_BGR2GRAY)
    else:
        original_gray = original
        compressed_gray = compressed

    # Calculate SSIM
    ssim_value = ssim(original_gray, compressed_gray)
    return ssim_value

# Directories where your images are saved
real_dir = '/content/drive/MyDrive/eval/actual'
fake_dir = '/content/drive/MyDrive/eval/fake'

ssim_values = []  # List to store SSIM values

# Loop over patient IDs 400 to 450 (inclusive)
for patient in range(400, 451):
    # Construct file paths using zero-padded numbering
    real_filename = f"patient{patient:04d}_actual.png"
    fake_filename = f"patient{patient:04d}_fake.png"
    real_path = os.path.join(real_dir, real_filename)
    fake_path = os.path.join(fake_dir, fake_filename)

    # Read images
    original = cv2.imread(real_path)
    compressed = cv2.imread(fake_path, 1)  # Color image

    # Check if images were loaded successfully
    if original is None or compressed is None:
        print(f"Warning: Could not load images for patient {patient}. Skipping this pair.")
        continue

    # If image sizes do not match, resize the compressed image to match the original
    if original.shape != compressed.shape:
        # cv2.resize expects size as (width, height)
        compressed = cv2.resize(compressed, (original.shape[1], original.shape[0]))

    # Compute SSIM for this pair
    ssim_value = calculate_SSIM(original, compressed)
    print(f"Patient {patient}: SSIM value is {ssim_value:.4f}")
    ssim_values.append(ssim_value)

# Compute and print the average SSIM if any valid pairs were found
if ssim_values:
    avg_ssim = np.mean(ssim_values)
    print(f"\nAverage SSIM over all valid image pairs: {avg_ssim:.4f}")
else:
    print("No valid image pairs found.")
# Out:
# Patient 400: SSIM value is 0.6140
# Patient 401: SSIM value is 0.6075
# Patient 402: SSIM value is 0.6159
# Patient 403: SSIM value is 0.6327
# Patient 404: SSIM value is 0.5986
# Patient 405: SSIM value is 0.5909
# Patient 406: SSIM value is 0.6121
# Patient 407: SSIM value is 0.6123
# Patient 408: SSIM value is 0.5954
# Patient 409: SSIM value is 0.6027
# Patient 410: SSIM value is 0.6036
# Patient 411: SSIM value is 0.5875
# Patient 412: SSIM value is 0.6211
# Patient 413: SSIM value is 0.5992
# Patient 414: SSIM value is 0.6154
# Patient 415: SSIM value is 0.5831
# Patient 416: SSIM value is 0.5960
# Patient 417: SSIM value is 0.6249
# Patient 418: SSIM value is 0.5582
# Patient 419: SSIM value is 0.5988
# Patient 420: SSIM value is 0.6104
# Patient 421: SSIM value is 0.5960
# Patient 422: SSIM value is 0.6133
# Patient 423: SSIM value is 0.6265
# Patient 424: SSIM value is 0.6056
# Patient 425: SSIM value is 0.6108
# Patient 426: SSIM value is 0.6193
# Patient 427: SSIM value is 0.6254
# Patient 428: SSIM value is 0.6055
# Patient 429: SSIM value is 0.5893
# Patient 430: SSIM value is 0.5865
# Patient 431: SSIM value is 0.6098
# Patient 432: SSIM value is 0.6529
# Patient 433: SSIM value is 0.6151
# Patient 434: SSIM value is 0.6142
# Patient 435: SSIM value is 0.6129
# Patient 436: SSIM value is 0.6316
# Patient 437: SSIM value is 0.5956
# Patient 438: SSIM value is 0.5960
# Patient 439: SSIM value is 0.6377
# Patient 440: SSIM value is 0.6325
# Patient 441: SSIM value is 0.6285
# Patient 442: SSIM value is 0.6244
# Patient 443: SSIM value is 0.6021
# Patient 444: SSIM value is 0.6223
# Patient 445: SSIM value is 0.4912
# Patient 446: SSIM value is 0.5837
# Patient 447: SSIM value is 0.6225
# Patient 448: SSIM value is 0.6050
# Patient 449: SSIM value is 0.6215
# Patient 450: SSIM value is 0.5929
#
# Average SSIM over all valid image pairs: 0.6069
