# %%
# prompt: mount the drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# prompt: download the file the dock "https://humanheart-project.creatis.insa-lyon.fr/database/api/v1/collection/6373703d73e9f0047faa1bc8/download"

# !wget "https://humanheart-project.creatis.insa-lyon.fr/database/api/v1/collection/6373703d73e9f0047faa1bc8/download"
# Out:
# --2025-02-20 22:00:50--  https://humanheart-project.creatis.insa-lyon.fr/database/api/v1/collection/6373703d73e9f0047faa1bc8/download
# Resolving humanheart-project.creatis.insa-lyon.fr (humanheart-project.creatis.insa-lyon.fr)... 195.220.108.28
# Connecting to humanheart-project.creatis.insa-lyon.fr (humanheart-project.creatis.insa-lyon.fr)|195.220.108.28|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘download’
#
# download                [              <=>   ] 182.38M  12.9MB/s               ^C

# %%
# prompt: unzip the file "/content/download.2" and store it in path "/content/drive/MyDrive"

import zipfile
import os

# Define the paths
zip_file_path = "/content/download.2"
extract_path = "/content/drive/MyDrive"

# Check if the zip file exists
if os.path.exists(zip_file_path):
  # Create the extraction directory if it doesn't exist
  os.makedirs(extract_path, exist_ok=True)

  # Extract the zip file
  try:
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
      zip_ref.extractall(extract_path)
    print(f"Successfully extracted {zip_file_path} to {extract_path}")
  except zipfile.BadZipFile:
    print(f"Error: {zip_file_path} is not a valid zip file.")
  except Exception as e:
    print(f"An error occurred: {e}")
else:
  print(f"Error: {zip_file_path} not found.")
# Out:
# Error: /content/download.2 not found.

# %%
import os
import nibabel as nib
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
import cv2
from skimage.transform import resize
from tqdm import tqdm

# %%
DATASET_PATH = "/content/drive/MyDrive/CAMUS_public/database_nifti/"

# %%
# !pip install nibabel numpy matplotlib tensorflow keras tqdm scikit-image opencv-python
# nibabel numpy matplotlib tensorflow keras tqdm scikit-image opencv-python # Libraries used in this notebook
# Out:
# Requirement already satisfied: nibabel in /usr/local/lib/python3.11/dist-packages (5.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (3.8.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (0.25.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.11/dist-packages (from nibabel) (6.5.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from nibabel) (24.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.11/dist-packages (from nibabel) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras) (0.14.0)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (1.13.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2025.1.10)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (0.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)

# %%
import os
import numpy as np
import nibabel as nib
from tqdm import tqdm

DATASET_PATH = "/content/drive/MyDrive/CAMUS_public/database_nifti"
OUTPUT_PATH = "/content/drive/MyDrive/CAMUS_processed"  # New identical folder structure

def preprocess_image(file_path):
    """Loads and normalizes a NIfTI image."""
    if not os.path.exists(file_path):
        return None
    img = nib.load(file_path).get_fdata()
    img = np.squeeze(img)  # Ensure it's 2D
    img = (img - np.min(img)) / (np.max(img) - np.min(img) + 1e-8)  # Normalize
    return img.astype(np.float32)

def collect_view_data(view):
    """Collects image-ground truth pairs for ES and ED phases of a specific view (2CH or 4CH)
       and saves them into an identical new folder structure."""
    phases = ["ES", "ED"]  # Only ES and ED phases

    patients = sorted(os.listdir(DATASET_PATH))

    for patient in tqdm(patients):
        patient_path = os.path.join(DATASET_PATH, patient)
        new_patient_path = os.path.join(OUTPUT_PATH, patient)
        if not os.path.isdir(patient_path):
            continue

        os.makedirs(new_patient_path, exist_ok=True)

        try:
            for phase in phases:
                img_path = os.path.join(patient_path, f"{patient}_{view}_{phase}.nii.gz")
                seg_path = os.path.join(patient_path, f"{patient}_{view}_{phase}_gt.nii.gz")

                img = preprocess_image(img_path)
                seg = preprocess_image(seg_path)

                if img is not None and seg is not None:
                    # Create output file path inside the new patient folder
                    output_file_path = os.path.join(new_patient_path, f"{patient}_{view}_{phase}.npz")

                    # Save the image and segmentation data to a .npz file
                    np.savez_compressed(output_file_path, image=img, segmentation=seg)

        except Exception as e:
            print(f"Error processing {patient} for {view}: {e}")

    print(f"Data for {view} view saved in the new identical folder structure")

# Process 2CH and 4CH views for ES and ED phases
print("\nProcessing 2CH view...")
collect_view_data("2CH")

print("\nProcessing 4CH view...")
collect_view_data("4CH")
# Out:
# Processing 2CH view...
# 100%|██████████| 501/501 [27:45<00:00,  3.32s/it]
# Data for 2CH view saved in the new identical folder structure
#
# Processing 4CH view...
# 100%|██████████| 501/501 [29:56<00:00,  3.59s/it]
# Data for 4CH view saved in the new identical folder structure

# %%
import os
import numpy as np
import tensorflow as tf
import cv2  # OpenCV for image saving
from tqdm import tqdm  # Progress bar

# Define paths
PROCESSED_DATASET_PATH = "/content/drive/MyDrive/CAMUS_processed"
OUTPUT_PATH = "/content/drive/MyDrive/CAMPUS_GAN_INPUT"

# Create output directories
os.makedirs(os.path.join(OUTPUT_PATH, "X_train_ES"), exist_ok=True)
os.makedirs(os.path.join(OUTPUT_PATH, "Y_train_ES"), exist_ok=True)
os.makedirs(os.path.join(OUTPUT_PATH, "X_train_ED"), exist_ok=True)
os.makedirs(os.path.join(OUTPUT_PATH, "Y_train_ED"), exist_ok=True)

def load_and_save_data(phase):
    """Loads 2CH and 4CH pairs for a given phase (ES or ED), preprocesses them for GANs, and saves as images."""

    patients = sorted(os.listdir(PROCESSED_DATASET_PATH))

    for patient in tqdm(patients, desc=f"Processing {phase} data"):
        patient_path = os.path.join(PROCESSED_DATASET_PATH, patient)

        if not os.path.isdir(patient_path):
            continue

        # Define file paths
        input_file = os.path.join(patient_path, f"{patient}_2CH_{phase}.npz")
        target_file = os.path.join(patient_path, f"{patient}_4CH_{phase}.npz")

        if os.path.exists(input_file) and os.path.exists(target_file):
            try:
                # Load data
                input_data = np.load(input_file)
                target_data = np.load(target_file)

                input_image = input_data['image']
                target_image = target_data['image']

                # Normalize to [-1, 1] for GAN training
                input_image = (input_image.astype(np.float32) / 127.5) - 1
                target_image = (target_image.astype(np.float32) / 127.5) - 1

                # Convert to uint8 (scale back to [0, 255] for saving as PNG)
                input_image_save = ((input_image + 1) * 127.5).astype(np.uint8)
                target_image_save = ((target_image + 1) * 127.5).astype(np.uint8)

                # Ensure images are 2D (grayscale)
                if input_image_save.ndim == 3:
                    input_image_save = input_image_save[:, :, 0]
                if target_image_save.ndim == 3:
                    target_image_save = target_image_save[:, :, 0]

                # Save images
                cv2.imwrite(os.path.join(OUTPUT_PATH, f"X_train_{phase}", f"{patient}.png"), input_image_save)
                cv2.imwrite(os.path.join(OUTPUT_PATH, f"Y_train_{phase}", f"{patient}.png"), target_image_save)

            except Exception as e:
                print(f"Error processing {patient} for {phase}: {e}")

# Process and save both ES and ED phases
load_and_save_data("ES")
load_and_save_data("ED")

print("GAN-compatible images saved successfully.")
# Out:
# Processing ES data: 100%|██████████| 500/500 [06:44<00:00,  1.24it/s]
# Processing ED data: 100%|██████████| 500/500 [06:43<00:00,  1.24it/s]
# GAN-compatible images saved successfully.

# %%
import os
import numpy as np
import nibabel as nib
import cv2
from tqdm import tqdm

DATASET_PATH = "/content/drive/MyDrive/CAMUS_public/database_nifti"
OUTPUT_PATH = "/content/drive/MyDrive/CAMUS_GAN_Processed"

# Use uppercase phases to match actual filenames
PHASES = ["ES", "ED"]
VIEWS = ["2CH", "4CH"]

def normalize_image(image):
    image = image.astype(np.float32)
    image = (image - np.min(image)) / (np.max(image) - np.min(image) + 1e-8)
    return (image * 2) - 1

def process_nifti_images():
    for patient_dir in tqdm(sorted(os.listdir(DATASET_PATH))):
        patient_path = os.path.join(DATASET_PATH, patient_dir)

        if not os.path.isdir(patient_path):
            continue

        # Extract patient number (assuming format "patientXXXX")
        patient_number = patient_dir.replace("patient", "")

        for phase in PHASES:
            for view in VIEWS:
                # Construct correct filename pattern
                base_name = f"patient{patient_number}_{view}_{phase}"
                original_file = os.path.join(patient_path, f"{base_name}.nii.gz")
                ground_file = os.path.join(patient_path, f"{base_name}_gt.nii.gz")

                # Create output directory
                output_dir = os.path.join(OUTPUT_PATH, phase.lower(), view, f"patient{patient_number}")
                os.makedirs(output_dir, exist_ok=True)

                # Process original image
                if os.path.exists(original_file):
                    try:
                        img = nib.load(original_file).get_fdata()
                        # Check dimensions before slicing
                        if img.ndim == 3:
                            img_slice = img[:, :, 0]  # First temporal slice if 3D
                        elif img.ndim == 2:
                            img_slice = img  # Already 2D
                        else:
                            raise ValueError(f"Unexpected number of dimensions: {img.ndim}")

                        norm_img = normalize_image(img_slice)
                        out_path = os.path.join(output_dir, f"{base_name}_original.png")
                        cv2.imwrite(out_path, ((norm_img + 1) * 127.5).astype(np.uint8))
                    except Exception as e:
                        print(f"Error with {original_file}: {str(e)}")

                # Process ground truth
                if os.path.exists(ground_file):
                    try:
                        gt = nib.load(ground_file).get_fdata()
                        if gt.ndim == 3:
                            gt_slice = gt[:, :, 0]
                        elif gt.ndim == 2:
                            gt_slice = gt
                        else:
                            raise ValueError(f"Unexpected number of dimensions: {gt.ndim}")

                        norm_gt = normalize_image(gt_slice)
                        out_path = os.path.join(output_dir, f"{base_name}_ground.png")
                        cv2.imwrite(out_path, ((norm_gt + 1) * 127.5).astype(np.uint8))
                    except Exception as e:
                        print(f"Error with {ground_file}: {str(e)}")

process_nifti_images()
print("✅ Processing complete")
# Out:
# 100%|██████████| 501/501 [28:29<00:00,  3.41s/it]
# ✅ Processing complete

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import cv2

# %%
import tensorflow as tf
from tensorflow.keras import layers

IMG_HEIGHT, IMG_WIDTH = 256, 256  # Assuming images are resized to 256x256

# ---------- Generator (U-Net Based) ----------
def build_generator(input_shape=(IMG_HEIGHT, IMG_WIDTH, 2)):
    inputs = tf.keras.Input(shape=input_shape)

    # Encoder: Downsampling layers
    def downsample(x, filters, kernel_size=4, apply_batchnorm=True):
        x = layers.Conv2D(filters, kernel_size, strides=2, padding='same', use_bias=False)(x)
        if apply_batchnorm:
            x = layers.BatchNormalization()(x)
        x = layers.LeakyReLU()(x)
        return x

    # Decoder: Upsampling layers with skip connections
    def upsample(x, skip, filters, kernel_size=4, apply_dropout=False):
        x = layers.Conv2DTranspose(filters, kernel_size, strides=2, padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        if apply_dropout:
            x = layers.Dropout(0.5)(x)
        x = layers.ReLU()(x)
        x = layers.Concatenate()([x, skip])
        return x

    # Downsampling path
    d1 = downsample(inputs, 64, apply_batchnorm=False)         # (128x128x64)
    d2 = downsample(d1, 128)                                     # (64x64x128)
    d3 = downsample(d2, 256)                                     # (32x32x256)
    d4 = downsample(d3, 512)                                     # (16x16x512)
    d5 = downsample(d4, 512)                                     # (8x8x512)

    # Bottleneck
    bottleneck = layers.Conv2D(512, 4, strides=2, padding='same', use_bias=False)(d5)  # (4x4x512)
    bottleneck = layers.ReLU()(bottleneck)

    # Upsampling path with skip connections
    u1 = layers.Conv2DTranspose(512, 4, strides=2, padding='same', use_bias=False)(bottleneck)
    u1 = layers.BatchNormalization()(u1)
    u1 = layers.Dropout(0.5)(u1)
    u1 = layers.ReLU()(u1)
    u1 = layers.Concatenate()([u1, d5])                           # (8x8x1024)

    u2 = upsample(u1, d4, 512, apply_dropout=True)               # (16x16x1024)
    u3 = upsample(u2, d3, 256)                                   # (32x32x512)
    u4 = upsample(u3, d2, 128)                                   # (64x64x256)
    u5 = upsample(u4, d1, 64)                                    # (128x128x128)

    u6 = layers.Conv2DTranspose(32, 4, strides=2, padding='same', use_bias=False)(u5)  # (256x256x32)
    u6 = layers.BatchNormalization()(u6)
    u6 = layers.ReLU()(u6)

    # Final layer: Output 2 channels (synthetic 4CH image & segmentation mask)
    outputs = layers.Conv2D(2, 4, strides=1, padding='same', activation='tanh')(u6)
    return tf.keras.Model(inputs, outputs, name='generator')

# ---------- Discriminator (PatchGAN) ----------
def build_discriminator(input_shape=(IMG_HEIGHT, IMG_WIDTH, 4)):
    inp = tf.keras.Input(shape=input_shape)
    x = layers.Conv2D(64, 4, strides=2, padding='same')(inp)
    x = layers.LeakyReLU()(x)
    x = layers.Conv2D(128, 4, strides=2, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)
    x = layers.Conv2D(256, 4, strides=2, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)
    x = layers.Conv2D(512, 4, strides=1, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)
    outputs = layers.Conv2D(1, 4, strides=1, padding='same')(x)
    return tf.keras.Model(inp, outputs, name='discriminator')

# Instantiate models
generator = build_generator()
discriminator = build_discriminator()

# ---------- Loss Functions and Optimizers ----------
bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
mae = tf.keras.losses.MeanAbsoluteError()

def discriminator_loss(real_output, fake_output):
    real_loss = bce(tf.ones_like(real_output), real_output)
    fake_loss = bce(tf.zeros_like(fake_output), fake_output)
    return real_loss + fake_loss

def generator_loss(fake_output, gen_output, target, lambda_L1=100):
    gan_loss = bce(tf.ones_like(fake_output), fake_output)
    l1_loss = mae(target, gen_output)
    return gan_loss + lambda_L1 * l1_loss

optimizer_gen = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
optimizer_disc = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# %%
# prompt: for the upper code, generte the model summary table for both generator and discriminator

generator.summary()
discriminator.summary()
# Out:
# Model: "generator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 2)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 128, 128, 64)   │          2,048 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu (LeakyReLU)   │ (None, 128, 128, 64)   │              0 │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 64, 64, 128)    │        131,072 │ leaky_re_lu[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 64, 64, 128)    │            512 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU) │ (None, 64, 64, 128)    │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 32, 32, 256)    │        524,288 │ leaky_re_lu_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 32, 32, 256)    │          1,024 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_2 (LeakyReLU) │ (None, 32, 32, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 16, 16, 512)    │      2,097,152 │ leaky_re_lu_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 16, 16, 512)    │          2,048 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_3 (LeakyReLU) │ (None, 16, 16, 512)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 8, 8, 512)      │      4,194,304 │ leaky_re_lu_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 8, 8, 512)      │          2,048 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_4 (LeakyReLU) │ (None, 8, 8, 512)      │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 4, 4, 512)      │      4,194,304 │ leaky_re_lu_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu (ReLU)              │ (None, 4, 4, 512)      │              0 │ conv2d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 8, 8, 512)      │      4,194,304 │ re_lu[0][0]            │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 8, 8, 512)      │          2,048 │ conv2d_transpose[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 8, 8, 512)      │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1 (ReLU)            │ (None, 8, 8, 512)      │              0 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 8, 8, 1024)     │              0 │ re_lu_1[0][0],         │
# │                           │                        │                │ leaky_re_lu_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 16, 16, 512)    │      8,388,608 │ concatenate[0][0]      │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 16, 16, 512)    │          2,048 │ conv2d_transpose_1[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 16, 16, 512)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_2 (ReLU)            │ (None, 16, 16, 512)    │              0 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 16, 16, 1024)   │              0 │ re_lu_2[0][0],         │
# │ (Concatenate)             │                        │                │ leaky_re_lu_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 32, 32, 256)    │      4,194,304 │ concatenate_1[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 32, 32, 256)    │          1,024 │ conv2d_transpose_2[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_3 (ReLU)            │ (None, 32, 32, 256)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 32, 32, 512)    │              0 │ re_lu_3[0][0],         │
# │ (Concatenate)             │                        │                │ leaky_re_lu_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 64, 64, 128)    │      1,048,576 │ concatenate_2[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 64, 64, 128)    │            512 │ conv2d_transpose_3[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_4 (ReLU)            │ (None, 64, 64, 128)    │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 64, 64, 256)    │              0 │ re_lu_4[0][0],         │
# │ (Concatenate)             │                        │                │ leaky_re_lu_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_4        │ (None, 128, 128, 64)   │        262,144 │ concatenate_3[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 128, 128, 64)   │            256 │ conv2d_transpose_4[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_5 (ReLU)            │ (None, 128, 128, 64)   │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 128, 128, 128)  │              0 │ re_lu_5[0][0],         │
# │ (Concatenate)             │                        │                │ leaky_re_lu[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_5        │ (None, 256, 256, 32)   │         65,536 │ concatenate_4[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 256, 256, 32)   │            128 │ conv2d_transpose_5[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_6 (ReLU)            │ (None, 256, 256, 32)   │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 256, 256, 2)    │          1,026 │ re_lu_6[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 29,309,314 (111.81 MB)
#  Trainable params: 29,303,490 (111.78 MB)
#  Non-trainable params: 5,824 (22.75 KB)
# Model: "discriminator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 256, 256, 4)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 128, 128, 64)        │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_5 (LeakyReLU)            │ (None, 128, 128, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 64, 64, 128)         │         131,072 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_10               │ (None, 64, 64, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_6 (LeakyReLU)            │ (None, 64, 64, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 32, 32, 256)         │         524,288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_11               │ (None, 32, 32, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_7 (LeakyReLU)            │ (None, 32, 32, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 32, 32, 512)         │       2,097,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_12               │ (None, 32, 32, 512)         │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_8 (LeakyReLU)            │ (None, 32, 32, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 32, 32, 1)           │           8,193 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,768,449 (10.56 MB)
#  Trainable params: 2,766,657 (10.55 MB)
#  Non-trainable params: 1,792 (7.00 KB)

# %%
import os
import tensorflow as tf
import cv2

OUTPUT_PATH = "/content/drive/MyDrive/CAMUS_GAN_Processed"
IMG_HEIGHT, IMG_WIDTH = 256, 256  # Ensure consistency

# ---------- Data Loading Functions ----------
def load_image(path):
    image = tf.io.read_file(path)
    image = tf.image.decode_png(image, channels=1)
    image = tf.cast(image, tf.float32)
    image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH])
    image = (image / 127.5) - 1  # Scale [0,255] -> [-1,1]
    return image

def load_pair(phase, patient, view_input='2CH', view_target='4CH'):
    """
    For a given phase (e.g., "ed" or "es") and patient (e.g., "0001"),
    load the 2CH images (original and ground) and 4CH images (original and ground)
    and return them as concatenated pairs.
    """
    base_name_input = f"patient{patient}_{view_input}_{phase.upper()}"
    base_name_target = f"patient{patient}_{view_target}_{phase.upper()}"

    input_dir = os.path.join(OUTPUT_PATH, phase, view_input, f"patient{patient}")
    target_dir = os.path.join(OUTPUT_PATH, phase, view_target, f"patient{patient}")

    input_original_path = os.path.join(input_dir, f"{base_name_input}_original.png")
    input_ground_path   = os.path.join(input_dir, f"{base_name_input}_ground.png")
    target_original_path = os.path.join(target_dir, f"{base_name_target}_original.png")
    target_ground_path   = os.path.join(target_dir, f"{base_name_target}_ground.png")

    input_image = load_image(input_original_path)
    input_mask  = load_image(input_ground_path)
    target_image = load_image(target_original_path)
    target_mask  = load_image(target_ground_path)

    # Concatenate to form 2-channel inputs for condition and target respectively
    condition = tf.concat([input_image, input_mask], axis=-1)  # Shape: (256,256,2)
    target    = tf.concat([target_image, target_mask], axis=-1)  # Shape: (256,256,2)
    return condition, target

def create_dataset(phase, patient_list, batch_size=8):
    conditions, targets = [], []
    for patient in patient_list:
        try:
            cond, targ = load_pair(phase, patient)
            conditions.append(cond)
            targets.append(targ)
        except Exception as e:
            print(f"Error loading patient {patient}: {e}")
    conditions = tf.stack(conditions)
    targets = tf.stack(targets)
    dataset = tf.data.Dataset.from_tensor_slices((conditions, targets))
    dataset = dataset.shuffle(buffer_size=len(conditions)).batch(batch_size)
    return dataset

# ---------- Training Parameters and Dataset ----------
EPOCHS = 300
BATCH_SIZE = 8
# Example patient list; extend as needed
# patient_list = ["0001", "0002", "0003","0004","0005","0006","0007"]
patient_list = [f"{i:04d}" for i in range(1, 400)]

# Create training dataset for a specific phase (e.g., "ed" for diastolic)
train_dataset = create_dataset("ed", patient_list, batch_size=BATCH_SIZE)

# ---------- Training Step ----------
@tf.function
def train_step(condition, target):
    with tf.GradientTape(persistent=True) as tape:
        # Generator produces fake 4CH pair given the 2CH condition pair
        fake_target = generator(condition, training=True)

        # For the conditional discriminator: concatenate the condition with the target
        real_input = tf.concat([condition, target], axis=-1)     # Shape: (256,256,4)
        fake_input = tf.concat([condition, fake_target], axis=-1)  # Shape: (256,256,4)

        # Discriminator outputs
        disc_real = discriminator(real_input, training=True)
        disc_fake = discriminator(fake_input, training=True)

        # Compute losses
        gen_loss = generator_loss(disc_fake, fake_target, target)
        disc_loss = discriminator_loss(disc_real, disc_fake)

    # Compute gradients and update weights
    gradients_gen = tape.gradient(gen_loss, generator.trainable_variables)
    gradients_disc = tape.gradient(disc_loss, discriminator.trainable_variables)
    optimizer_gen.apply_gradients(zip(gradients_gen, generator.trainable_variables))
    optimizer_disc.apply_gradients(zip(gradients_disc, discriminator.trainable_variables))

    return gen_loss, disc_loss

# ---------- Training Loop ----------
for epoch in range(EPOCHS):
    print(f"Epoch {epoch+1}/{EPOCHS}")
    for condition, target in train_dataset:
        g_loss, d_loss = train_step(condition, target)
    print(f"  Generator Loss: {g_loss.numpy():.4f} | Discriminator Loss: {d_loss.numpy():.4f}")

# Optionally, save the models after training:
generator.save(os.path.join(OUTPUT_PATH, "generator_ed_LATEST300.h5"))
discriminator.save(os.path.join(OUTPUT_PATH, "discriminator_ed_LATEST300.h5"))
# Out:
# Epoch 1/300
#   Generator Loss: 18.7710 | Discriminator Loss: 0.4746
# Epoch 2/300
#   Generator Loss: 16.1968 | Discriminator Loss: 0.9739
# Epoch 3/300
#   Generator Loss: 14.8159 | Discriminator Loss: 0.8542
# Epoch 4/300
#   Generator Loss: 15.3841 | Discriminator Loss: 0.8077
# Epoch 5/300
#   Generator Loss: 11.9151 | Discriminator Loss: 1.1175
# Epoch 6/300
#   Generator Loss: 14.3488 | Discriminator Loss: 1.1211
# Epoch 7/300
#   Generator Loss: 16.3625 | Discriminator Loss: 1.2438
# Epoch 8/300
#   Generator Loss: 14.4071 | Discriminator Loss: 1.0766
# Epoch 9/300
#   Generator Loss: 12.8136 | Discriminator Loss: 1.4888
# Epoch 10/300
#   Generator Loss: 15.5015 | Discriminator Loss: 0.9052
# Epoch 11/300
#   Generator Loss: 14.1034 | Discriminator Loss: 0.9654
# Epoch 12/300
#   Generator Loss: 12.3265 | Discriminator Loss: 1.1840
# Epoch 13/300
#   Generator Loss: 14.1025 | Discriminator Loss: 1.0430
# Epoch 14/300
#   Generator Loss: 13.7661 | Discriminator Loss: 0.8329
# Epoch 15/300
#   Generator Loss: 11.1524 | Discriminator Loss: 1.4462
# Epoch 16/300
#   Generator Loss: 10.2419 | Discriminator Loss: 1.1017
# Epoch 17/300
#   Generator Loss: 10.5107 | Discriminator Loss: 0.8899
# Epoch 18/300
#   Generator Loss: 10.7556 | Discriminator Loss: 1.0778
# Epoch 19/300
#   Generator Loss: 8.9601 | Discriminator Loss: 1.2542
# Epoch 20/300
#   Generator Loss: 7.5732 | Discriminator Loss: 1.4540
# Epoch 21/300
#   Generator Loss: 9.5207 | Discriminator Loss: 1.1059
# Epoch 22/300
#   Generator Loss: 8.4270 | Discriminator Loss: 1.1651
# Epoch 23/300
#   Generator Loss: 9.5081 | Discriminator Loss: 1.4357
# Epoch 24/300
#   Generator Loss: 8.4530 | Discriminator Loss: 1.0802
# Epoch 25/300
#   Generator Loss: 7.7285 | Discriminator Loss: 1.4718
# Epoch 26/300
#   Generator Loss: 8.5701 | Discriminator Loss: 1.1606
# Epoch 27/300
#   Generator Loss: 7.1424 | Discriminator Loss: 1.1809
# Epoch 28/300
#   Generator Loss: 7.2494 | Discriminator Loss: 1.3941
# Epoch 29/300
#   Generator Loss: 7.9204 | Discriminator Loss: 0.8910
# Epoch 30/300
#   Generator Loss: 7.6345 | Discriminator Loss: 1.2009
# Epoch 31/300
#   Generator Loss: 7.2950 | Discriminator Loss: 1.1568
# Epoch 32/300
#   Generator Loss: 6.9058 | Discriminator Loss: 1.0752
# Epoch 33/300
#   Generator Loss: 6.8331 | Discriminator Loss: 1.2044
# Epoch 34/300
#   Generator Loss: 6.7923 | Discriminator Loss: 1.4364
# Epoch 35/300
#   Generator Loss: 6.4471 | Discriminator Loss: 1.1460
# Epoch 36/300
#   Generator Loss: 7.3994 | Discriminator Loss: 1.1310
# Epoch 37/300
#   Generator Loss: 6.6451 | Discriminator Loss: 1.1139
# Epoch 38/300
#   Generator Loss: 6.7506 | Discriminator Loss: 1.1271
# Epoch 39/300
#   Generator Loss: 6.1038 | Discriminator Loss: 1.3144
# Epoch 40/300
#   Generator Loss: 6.5359 | Discriminator Loss: 1.1663
# Epoch 41/300
#   Generator Loss: 6.7652 | Discriminator Loss: 1.1583
# Epoch 42/300
#   Generator Loss: 6.2845 | Discriminator Loss: 1.1891
# Epoch 43/300
#   Generator Loss: 6.1046 | Discriminator Loss: 1.3641
# Epoch 44/300
#   Generator Loss: 6.2251 | Discriminator Loss: 1.2626
# Epoch 45/300
#   Generator Loss: 6.1450 | Discriminator Loss: 1.2246
# Epoch 46/300
#   Generator Loss: 5.9044 | Discriminator Loss: 1.2831
# Epoch 47/300
#   Generator Loss: 6.4113 | Discriminator Loss: 1.3455
# Epoch 48/300
#   Generator Loss: 6.3116 | Discriminator Loss: 1.4654
# Epoch 49/300
#   Generator Loss: 6.9719 | Discriminator Loss: 1.3166
# Epoch 50/300
#   Generator Loss: 5.8083 | Discriminator Loss: 1.1802
# Epoch 51/300
#   Generator Loss: 5.9056 | Discriminator Loss: 1.1279
# Epoch 52/300
#   Generator Loss: 6.0469 | Discriminator Loss: 1.1206
# Epoch 53/300
#   Generator Loss: 6.6857 | Discriminator Loss: 1.3191
# Epoch 54/300
#   Generator Loss: 6.1598 | Discriminator Loss: 1.1221
# Epoch 55/300
#   Generator Loss: 6.3601 | Discriminator Loss: 1.1964
# Epoch 56/300
#   Generator Loss: 6.1895 | Discriminator Loss: 1.4310
# Epoch 57/300
#   Generator Loss: 6.1955 | Discriminator Loss: 1.2518
# Epoch 58/300
#   Generator Loss: 5.8813 | Discriminator Loss: 1.2758
# Epoch 59/300
#   Generator Loss: 5.8599 | Discriminator Loss: 1.1713
# Epoch 60/300
#   Generator Loss: 5.9923 | Discriminator Loss: 1.0255
# Epoch 61/300
#   Generator Loss: 5.3126 | Discriminator Loss: 1.1106
# Epoch 62/300
#   Generator Loss: 5.6792 | Discriminator Loss: 1.3762
# Epoch 63/300
#   Generator Loss: 5.8538 | Discriminator Loss: 1.2106
# Epoch 64/300
#   Generator Loss: 6.0367 | Discriminator Loss: 1.1005
# Epoch 65/300
#   Generator Loss: 5.7823 | Discriminator Loss: 1.1595
# Epoch 66/300
#   Generator Loss: 5.5172 | Discriminator Loss: 1.1867
# Epoch 67/300
#   Generator Loss: 6.3208 | Discriminator Loss: 1.4408
# Epoch 68/300
#   Generator Loss: 6.0431 | Discriminator Loss: 1.1076
# Epoch 69/300
#   Generator Loss: 5.7084 | Discriminator Loss: 1.2915
# Epoch 70/300
#   Generator Loss: 5.8683 | Discriminator Loss: 1.1557
# Epoch 71/300
#   Generator Loss: 5.6781 | Discriminator Loss: 1.1476
# Epoch 72/300
#   Generator Loss: 5.8196 | Discriminator Loss: 1.2779
# Epoch 73/300
#   Generator Loss: 4.8334 | Discriminator Loss: 1.3416
# Epoch 74/300
#   Generator Loss: 5.0805 | Discriminator Loss: 1.3590
# Epoch 75/300
#   Generator Loss: 5.1095 | Discriminator Loss: 1.3229
# Epoch 76/300
#   Generator Loss: 5.3682 | Discriminator Loss: 1.2826
# Epoch 77/300
#   Generator Loss: 5.1137 | Discriminator Loss: 1.3258
# Epoch 78/300
#   Generator Loss: 5.4814 | Discriminator Loss: 1.3064
# Epoch 79/300
#   Generator Loss: 5.1991 | Discriminator Loss: 1.2794
# Epoch 80/300
#   Generator Loss: 5.4101 | Discriminator Loss: 1.1420
# Epoch 81/300
#   Generator Loss: 5.8286 | Discriminator Loss: 1.3139
# Epoch 82/300
#   Generator Loss: 5.3227 | Discriminator Loss: 1.1006
# Epoch 83/300
#   Generator Loss: 5.4919 | Discriminator Loss: 1.1885
# Epoch 84/300
#   Generator Loss: 5.2138 | Discriminator Loss: 1.4996
# Epoch 85/300
#   Generator Loss: 5.3804 | Discriminator Loss: 1.2528
# Epoch 86/300
#   Generator Loss: 5.7301 | Discriminator Loss: 1.1459
# Epoch 87/300
#   Generator Loss: 5.0725 | Discriminator Loss: 1.2083
# Epoch 88/300
#   Generator Loss: 5.3669 | Discriminator Loss: 1.0954
# Epoch 89/300
#   Generator Loss: 5.2478 | Discriminator Loss: 1.2615
# Epoch 90/300
#   Generator Loss: 5.1981 | Discriminator Loss: 1.1550
# Epoch 91/300
#   Generator Loss: 5.9593 | Discriminator Loss: 1.0961
# Epoch 92/300
#   Generator Loss: 5.0106 | Discriminator Loss: 1.3239
# Epoch 93/300
#   Generator Loss: 5.1392 | Discriminator Loss: 1.0830
# Epoch 94/300
#   Generator Loss: 5.1787 | Discriminator Loss: 1.2867
# Epoch 95/300
#   Generator Loss: 4.9464 | Discriminator Loss: 1.2733
# Epoch 96/300
#   Generator Loss: 4.9095 | Discriminator Loss: 1.2796
# Epoch 97/300
#   Generator Loss: 5.3884 | Discriminator Loss: 1.3006
# Epoch 98/300
#   Generator Loss: 5.1152 | Discriminator Loss: 1.1587
# Epoch 99/300
#   Generator Loss: 5.0038 | Discriminator Loss: 1.2185
# Epoch 100/300
#   Generator Loss: 5.0750 | Discriminator Loss: 1.1942
# Epoch 101/300
#   Generator Loss: 4.9870 | Discriminator Loss: 1.1251
# Epoch 102/300
#   Generator Loss: 4.9738 | Discriminator Loss: 1.2300
# Epoch 103/300
#   Generator Loss: 5.0854 | Discriminator Loss: 1.2166
# Epoch 104/300
#   Generator Loss: 4.9549 | Discriminator Loss: 1.2377
# Epoch 105/300
#   Generator Loss: 4.7112 | Discriminator Loss: 1.1324
# Epoch 106/300
#   Generator Loss: 5.5481 | Discriminator Loss: 1.1609
# Epoch 107/300
#   Generator Loss: 4.8752 | Discriminator Loss: 1.1686
# Epoch 108/300
#   Generator Loss: 5.1414 | Discriminator Loss: 1.1599
# Epoch 109/300
#   Generator Loss: 6.1019 | Discriminator Loss: 1.8832
# Epoch 110/300
#   Generator Loss: 5.1506 | Discriminator Loss: 1.0558
# Epoch 111/300
#   Generator Loss: 5.2267 | Discriminator Loss: 1.0807
# Epoch 112/300
#   Generator Loss: 5.5771 | Discriminator Loss: 1.0433
# Epoch 113/300
#   Generator Loss: 4.9849 | Discriminator Loss: 1.1908
# Epoch 114/300
#   Generator Loss: 5.6091 | Discriminator Loss: 0.8917
# Epoch 115/300
#   Generator Loss: 5.0164 | Discriminator Loss: 1.0674
# Epoch 116/300
#   Generator Loss: 6.2257 | Discriminator Loss: 0.9341
# Epoch 117/300
#   Generator Loss: 4.9824 | Discriminator Loss: 1.2815
# Epoch 118/300
#   Generator Loss: 4.6548 | Discriminator Loss: 1.5166
# Epoch 119/300
#   Generator Loss: 4.5692 | Discriminator Loss: 1.3988
# Epoch 120/300
#   Generator Loss: 4.4762 | Discriminator Loss: 1.2128
# Epoch 121/300
#   Generator Loss: 4.4877 | Discriminator Loss: 1.2944
# Epoch 122/300
#   Generator Loss: 5.2182 | Discriminator Loss: 1.0036
# Epoch 123/300
#   Generator Loss: 5.0444 | Discriminator Loss: 1.0304
# Epoch 124/300
#   Generator Loss: 5.3426 | Discriminator Loss: 1.1425
# Epoch 125/300
#   Generator Loss: 5.1436 | Discriminator Loss: 1.2626
# Epoch 126/300
#   Generator Loss: 5.3554 | Discriminator Loss: 1.4336
# Epoch 127/300
#   Generator Loss: 4.4957 | Discriminator Loss: 1.3383
# Epoch 128/300
#   Generator Loss: 4.7042 | Discriminator Loss: 1.1321
# Epoch 129/300
#   Generator Loss: 4.9684 | Discriminator Loss: 1.1183
# Epoch 130/300
#   Generator Loss: 4.9914 | Discriminator Loss: 0.9934
# Epoch 131/300
#   Generator Loss: 4.8423 | Discriminator Loss: 0.9945
# Epoch 132/300
#   Generator Loss: 5.4030 | Discriminator Loss: 1.2951
# Epoch 133/300
#   Generator Loss: 5.8340 | Discriminator Loss: 1.2357
# Epoch 134/300
#   Generator Loss: 5.6160 | Discriminator Loss: 0.9494
# Epoch 135/300
#   Generator Loss: 5.5015 | Discriminator Loss: 1.0823
# Epoch 136/300
#   Generator Loss: 4.8848 | Discriminator Loss: 1.1492
# Epoch 137/300
#   Generator Loss: 5.3851 | Discriminator Loss: 1.0239
# Epoch 138/300
#   Generator Loss: 6.2671 | Discriminator Loss: 1.2175
# Epoch 139/300
#   Generator Loss: 5.5467 | Discriminator Loss: 0.9256
# Epoch 140/300
#   Generator Loss: 4.2763 | Discriminator Loss: 1.4183
# Epoch 141/300
#   Generator Loss: 4.7449 | Discriminator Loss: 1.2565
# Epoch 142/300
#   Generator Loss: 4.7945 | Discriminator Loss: 1.4102
# Epoch 143/300
#   Generator Loss: 4.7618 | Discriminator Loss: 1.0242
# Epoch 144/300
#   Generator Loss: 5.8152 | Discriminator Loss: 1.0817
# Epoch 145/300
#   Generator Loss: 4.9087 | Discriminator Loss: 0.9820
# Epoch 146/300
#   Generator Loss: 4.9768 | Discriminator Loss: 1.0533
# Epoch 147/300
#   Generator Loss: 4.8096 | Discriminator Loss: 1.0532
# Epoch 148/300
#   Generator Loss: 5.5111 | Discriminator Loss: 0.8194
# Epoch 149/300
#   Generator Loss: 6.0508 | Discriminator Loss: 0.9641
# Epoch 150/300
#   Generator Loss: 5.1669 | Discriminator Loss: 0.9412
# Epoch 151/300
#   Generator Loss: 5.7155 | Discriminator Loss: 0.9807
# Epoch 152/300
#   Generator Loss: 5.5344 | Discriminator Loss: 0.7669
# Epoch 153/300
#   Generator Loss: 6.6545 | Discriminator Loss: 6.0501
# Epoch 154/300
#   Generator Loss: 4.4130 | Discriminator Loss: 1.2687
# Epoch 155/300
#   Generator Loss: 4.7495 | Discriminator Loss: 1.1353
# Epoch 156/300
#   Generator Loss: 4.1306 | Discriminator Loss: 1.3736
# Epoch 157/300
#   Generator Loss: 4.3471 | Discriminator Loss: 1.2106
# Epoch 158/300
#   Generator Loss: 4.3743 | Discriminator Loss: 1.3523
# Epoch 159/300
#   Generator Loss: 4.3707 | Discriminator Loss: 1.2325
# Epoch 160/300
#   Generator Loss: 4.6630 | Discriminator Loss: 2.0369
# Epoch 161/300
#   Generator Loss: 4.4530 | Discriminator Loss: 1.2151
# Epoch 162/300
#   Generator Loss: 4.5104 | Discriminator Loss: 1.1529
# Epoch 163/300
#   Generator Loss: 5.3899 | Discriminator Loss: 1.1588
# Epoch 164/300
#   Generator Loss: 5.6491 | Discriminator Loss: 1.2405
# Epoch 165/300
#   Generator Loss: 5.1208 | Discriminator Loss: 0.7623
# Epoch 166/300
#   Generator Loss: 5.6660 | Discriminator Loss: 1.0353
# Epoch 167/300
#   Generator Loss: 5.6389 | Discriminator Loss: 1.2519
# Epoch 168/300
#   Generator Loss: 6.0087 | Discriminator Loss: 1.0176
# Epoch 169/300
#   Generator Loss: 5.3666 | Discriminator Loss: 0.8245
# Epoch 170/300
#   Generator Loss: 5.1616 | Discriminator Loss: 1.5821
# Epoch 171/300
#   Generator Loss: 5.2178 | Discriminator Loss: 0.8767
# Epoch 172/300
#   Generator Loss: 4.8238 | Discriminator Loss: 0.9052
# Epoch 173/300
#   Generator Loss: 4.9850 | Discriminator Loss: 1.5001
# Epoch 174/300
#   Generator Loss: 6.2519 | Discriminator Loss: 1.1103
# Epoch 175/300
#   Generator Loss: 4.8073 | Discriminator Loss: 0.8764
# Epoch 176/300
#   Generator Loss: 5.8176 | Discriminator Loss: 0.9665
# Epoch 177/300
#   Generator Loss: 4.7326 | Discriminator Loss: 1.2355
# Epoch 178/300
#   Generator Loss: 4.9130 | Discriminator Loss: 1.7324
# Epoch 179/300
#   Generator Loss: 4.6760 | Discriminator Loss: 1.4076
# Epoch 180/300
#   Generator Loss: 5.5373 | Discriminator Loss: 0.9847
# Epoch 181/300
#   Generator Loss: 5.3411 | Discriminator Loss: 0.8963
# Epoch 182/300
#   Generator Loss: 4.7909 | Discriminator Loss: 0.8908
# Epoch 183/300
#   Generator Loss: 5.9111 | Discriminator Loss: 1.1633
# Epoch 184/300
#   Generator Loss: 6.0634 | Discriminator Loss: 0.7702
# Epoch 185/300
#   Generator Loss: 5.8124 | Discriminator Loss: 0.9722
# Epoch 186/300
#   Generator Loss: 5.2021 | Discriminator Loss: 0.6369
# Epoch 187/300
#   Generator Loss: 5.7118 | Discriminator Loss: 0.7199
# Epoch 188/300
#   Generator Loss: 4.5836 | Discriminator Loss: 1.1692
# Epoch 189/300
#   Generator Loss: 4.4454 | Discriminator Loss: 1.3207
# Epoch 190/300
#   Generator Loss: 5.5172 | Discriminator Loss: 1.3235
# Epoch 191/300
#   Generator Loss: 4.9586 | Discriminator Loss: 0.9150
# Epoch 192/300
#   Generator Loss: 5.2770 | Discriminator Loss: 0.7061
# Epoch 193/300
#   Generator Loss: 5.3738 | Discriminator Loss: 0.8600
# Epoch 194/300
#   Generator Loss: 6.5823 | Discriminator Loss: 1.0135
# Epoch 195/300
#   Generator Loss: 5.4230 | Discriminator Loss: 0.6862
# Epoch 196/300
#   Generator Loss: 5.3519 | Discriminator Loss: 0.6645
# Epoch 197/300
#   Generator Loss: 5.7792 | Discriminator Loss: 0.6305
# Epoch 198/300
#   Generator Loss: 4.8483 | Discriminator Loss: 0.9697
# Epoch 199/300
#   Generator Loss: 5.2993 | Discriminator Loss: 0.7267
# Epoch 200/300
#   Generator Loss: 5.7040 | Discriminator Loss: 0.8559
# Epoch 201/300
#   Generator Loss: 5.9685 | Discriminator Loss: 0.8607
# Epoch 202/300
#   Generator Loss: 5.9244 | Discriminator Loss: 0.5926
# Epoch 203/300
#   Generator Loss: 4.5470 | Discriminator Loss: 1.4650
# Epoch 204/300
#   Generator Loss: 5.0657 | Discriminator Loss: 1.4903
# Epoch 205/300
#   Generator Loss: 5.4298 | Discriminator Loss: 0.8862
# Epoch 206/300
#   Generator Loss: 4.7503 | Discriminator Loss: 1.3066
# Epoch 207/300
#   Generator Loss: 4.7346 | Discriminator Loss: 1.1358
# Epoch 208/300
#   Generator Loss: 5.3992 | Discriminator Loss: 0.8277
# Epoch 209/300
#   Generator Loss: 7.4398 | Discriminator Loss: 0.9982
# Epoch 210/300
#   Generator Loss: 5.6165 | Discriminator Loss: 0.7234
# Epoch 211/300
#   Generator Loss: 4.6000 | Discriminator Loss: 1.3589
# Epoch 212/300
#   Generator Loss: 4.3806 | Discriminator Loss: 1.3030
# Epoch 213/300
#   Generator Loss: 4.5314 | Discriminator Loss: 1.2294
# Epoch 214/300
#   Generator Loss: 4.5732 | Discriminator Loss: 1.2655
# Epoch 215/300
#   Generator Loss: 4.4215 | Discriminator Loss: 1.3431
# Epoch 216/300
#   Generator Loss: 4.5292 | Discriminator Loss: 1.3132
# Epoch 217/300
#   Generator Loss: 4.1919 | Discriminator Loss: 1.3098
# Epoch 218/300
#   Generator Loss: 4.4174 | Discriminator Loss: 1.3719
# Epoch 219/300
#   Generator Loss: 4.6228 | Discriminator Loss: 1.0954
# Epoch 220/300
#   Generator Loss: 4.9727 | Discriminator Loss: 1.0776
# Epoch 221/300
#   Generator Loss: 4.4665 | Discriminator Loss: 0.9930
# Epoch 222/300
#   Generator Loss: 5.1074 | Discriminator Loss: 0.9087
# Epoch 223/300
#   Generator Loss: 5.5173 | Discriminator Loss: 1.0914
# Epoch 224/300
#   Generator Loss: 4.9597 | Discriminator Loss: 0.7865
# Epoch 225/300
#   Generator Loss: 5.8166 | Discriminator Loss: 0.6344
# Epoch 226/300
#   Generator Loss: 5.4850 | Discriminator Loss: 0.8367
# Epoch 227/300
#   Generator Loss: 6.5414 | Discriminator Loss: 0.5230
# Epoch 228/300
#   Generator Loss: 4.6728 | Discriminator Loss: 1.1645
# Epoch 229/300
#   Generator Loss: 4.4366 | Discriminator Loss: 1.1648
# Epoch 230/300
#   Generator Loss: 4.4978 | Discriminator Loss: 1.1083
# Epoch 231/300
#   Generator Loss: 4.7091 | Discriminator Loss: 0.9515
# Epoch 232/300
#   Generator Loss: 5.1302 | Discriminator Loss: 0.7335
# Epoch 233/300
#   Generator Loss: 4.5380 | Discriminator Loss: 0.8225
# Epoch 234/300
#   Generator Loss: 5.8819 | Discriminator Loss: 0.8163
# Epoch 235/300
#   Generator Loss: 5.2300 | Discriminator Loss: 0.7935
# Epoch 236/300
#   Generator Loss: 4.7174 | Discriminator Loss: 1.1390
# Epoch 237/300
#   Generator Loss: 4.7735 | Discriminator Loss: 0.7405
# Epoch 238/300
#   Generator Loss: 5.3124 | Discriminator Loss: 0.6322
# Epoch 239/300
#   Generator Loss: 5.3432 | Discriminator Loss: 0.7780
# Epoch 240/300
#   Generator Loss: 5.9692 | Discriminator Loss: 0.4930
# Epoch 241/300
#   Generator Loss: 5.4891 | Discriminator Loss: 0.6531
# Epoch 242/300
#   Generator Loss: 4.7572 | Discriminator Loss: 0.9864
# Epoch 243/300
#   Generator Loss: 6.7472 | Discriminator Loss: 0.8378
# Epoch 244/300
#   Generator Loss: 5.9114 | Discriminator Loss: 0.5915
# Epoch 245/300
#   Generator Loss: 4.4478 | Discriminator Loss: 1.1043
# Epoch 246/300
#   Generator Loss: 4.7587 | Discriminator Loss: 0.7660
# Epoch 247/300
#   Generator Loss: 5.3350 | Discriminator Loss: 0.6627
# Epoch 248/300
#   Generator Loss: 6.0486 | Discriminator Loss: 0.4806
# Epoch 249/300
#   Generator Loss: 5.7480 | Discriminator Loss: 0.5529
# Epoch 250/300
#   Generator Loss: 6.7210 | Discriminator Loss: 0.7124
# Epoch 251/300
#   Generator Loss: 6.2617 | Discriminator Loss: 0.7710
# Epoch 252/300
#   Generator Loss: 4.4495 | Discriminator Loss: 1.3499
# Epoch 253/300
#   Generator Loss: 4.4125 | Discriminator Loss: 1.2498
# Epoch 254/300
#   Generator Loss: 4.6489 | Discriminator Loss: 1.3839
# Epoch 255/300
#   Generator Loss: 4.4381 | Discriminator Loss: 1.3133
# Epoch 256/300
#   Generator Loss: 4.7778 | Discriminator Loss: 1.1966
# Epoch 257/300
#   Generator Loss: 4.1567 | Discriminator Loss: 1.3753
# Epoch 258/300
#   Generator Loss: 4.4075 | Discriminator Loss: 1.5902
# Epoch 259/300
#   Generator Loss: 4.6687 | Discriminator Loss: 1.0964
# Epoch 260/300
#   Generator Loss: 4.2282 | Discriminator Loss: 1.3061
# Epoch 261/300
#   Generator Loss: 4.2357 | Discriminator Loss: 1.2046
# Epoch 262/300
#   Generator Loss: 4.5331 | Discriminator Loss: 1.0986
# Epoch 263/300
#   Generator Loss: 5.8791 | Discriminator Loss: 0.9206
# Epoch 264/300
#   Generator Loss: 4.9608 | Discriminator Loss: 0.8885
# Epoch 265/300
#   Generator Loss: 4.2269 | Discriminator Loss: 1.3989
# Epoch 266/300
#   Generator Loss: 4.5802 | Discriminator Loss: 1.3105
# Epoch 267/300
#   Generator Loss: 5.6784 | Discriminator Loss: 1.0173
# Epoch 268/300
#   Generator Loss: 4.7213 | Discriminator Loss: 0.8664
# Epoch 269/300
#   Generator Loss: 5.4755 | Discriminator Loss: 0.8841
# Epoch 270/300
#   Generator Loss: 5.3364 | Discriminator Loss: 0.6006
# Epoch 271/300
#   Generator Loss: 4.8080 | Discriminator Loss: 0.8893
# Epoch 272/300
#   Generator Loss: 5.5503 | Discriminator Loss: 0.5618
# Epoch 273/300
#   Generator Loss: 4.9799 | Discriminator Loss: 0.7621
# Epoch 274/300
#   Generator Loss: 4.1486 | Discriminator Loss: 1.2888
# Epoch 275/300
#   Generator Loss: 5.1515 | Discriminator Loss: 0.6825
# Epoch 276/300
#   Generator Loss: 5.4930 | Discriminator Loss: 0.7739
# Epoch 277/300
#   Generator Loss: 4.4352 | Discriminator Loss: 1.0241
# Epoch 278/300
#   Generator Loss: 5.9675 | Discriminator Loss: 0.6362
# Epoch 279/300
#   Generator Loss: 4.9397 | Discriminator Loss: 0.9925
# Epoch 280/300
#   Generator Loss: 6.4915 | Discriminator Loss: 1.2051
# Epoch 281/300
#   Generator Loss: 6.2989 | Discriminator Loss: 0.9125
# Epoch 282/300
#   Generator Loss: 4.3929 | Discriminator Loss: 1.0869
# Epoch 283/300
#   Generator Loss: 6.2984 | Discriminator Loss: 0.9502
# Epoch 284/300
#   Generator Loss: 3.8309 | Discriminator Loss: 1.3747
# Epoch 285/300
#   Generator Loss: 3.9741 | Discriminator Loss: 1.3183
# Epoch 286/300
#   Generator Loss: 4.1685 | Discriminator Loss: 1.2466
# Epoch 287/300
#   Generator Loss: 3.7656 | Discriminator Loss: 1.2406
# Epoch 288/300
#   Generator Loss: 3.8473 | Discriminator Loss: 1.2775
# Epoch 289/300
#   Generator Loss: 3.8677 | Discriminator Loss: 1.4425
# Epoch 290/300
#   Generator Loss: 4.1066 | Discriminator Loss: 1.2492
# Epoch 291/300
#   Generator Loss: 3.8180 | Discriminator Loss: 1.3659
# Epoch 292/300
#   Generator Loss: 4.0369 | Discriminator Loss: 1.3607
# Epoch 293/300
#   Generator Loss: 3.9796 | Discriminator Loss: 1.3500
# Epoch 294/300
#   Generator Loss: 4.3398 | Discriminator Loss: 1.1035
# Epoch 295/300
#   Generator Loss: 3.9082 | Discriminator Loss: 1.2584
# Epoch 296/300
#   Generator Loss: 4.8116 | Discriminator Loss: 1.3995
# Epoch 297/300
#   Generator Loss: 4.8024 | Discriminator Loss: 0.8277
# Epoch 298/300
#   Generator Loss: 8.5415 | Discriminator Loss: 0.0528
# Epoch 299/300
#   Generator Loss: 4.3351 | Discriminator Loss: 1.2632
# Epoch 300/300
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#   Generator Loss: 4.6560 | Discriminator Loss: 0.8144
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow as tf

generator = tf.keras.models.load_model("/content/drive/MyDrive/CAMUS_GAN_Processed/generator_keras_ed_LATEST300.keras", compile=False)
discriminator = tf.keras.models.load_model("/content/drive/MyDrive/CAMUS_GAN_Processed/discriminator_keras_ed_LATEST300.keras", compile=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-a18572ec6ab9> in <cell line: 0>()
#       1 import tensorflow as tf
#       2
# ----> 3 generator = tf.keras.models.load_model("/content/drive/MyDrive/CAMUS_GAN_Processed/generator_keras_ed_LATEST300.keras", compile=False)
#       4 discriminator = tf.keras.models.load_model("/content/drive/MyDrive/CAMUS_GAN_Processed/discriminator_keras_ed_LATEST300.keras", compile=False)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     198         )
#     199     elif str(filepath).endswith(".keras"):
# --> 200         raise ValueError(
#     201             f"File not found: filepath={filepath}. "
#     202             "Please ensure the file is an accessible `.keras` "
#
# ValueError: File not found: filepath=/content/drive/MyDrive/CAMUS_GAN_Processed/generator_keras_ed_LATEST300.keras. Please ensure the file is an accessible `.keras` zip file.

# %%
import os
import cv2
import tensorflow as tf
import numpy as np

generator = tf.keras.models.load_model("/content/drive/MyDrive/CAMUS_GAN_Processed/generator_ed_LATEST300.h5", compile=False)
discriminator = tf.keras.models.load_model("/content/drive/MyDrive/CAMUS_GAN_Processed/discriminator_ed_LATEST300.h5", compile=False)

# ----- UNCOMMENT THIS SECTION WHEN LOADING THE MODEL FROM PREVIOUS BLOCK ----- #

OUTPUT_PATH = "/content/drive/MyDrive/CAMUS_GAN_Processed"

IMG_HEIGHT , IMG_WIDTH = 256 , 256

def load_image(path):
    image = tf.io.read_file(path)
    image = tf.image.decode_png(image, channels=1)
    image = tf.cast(image, tf.float32)
    image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH])
    image = (image / 127.5) - 1  # Scale [0,255] -> [-1,1]
    return image


def load_pair(phase, patient, view_input='2CH', view_target='4CH'):
    """
    For a given phase (e.g., "ed" or "es") and patient (e.g., "0001"),
    load the 2CH images (original and ground) and 4CH images (original and ground)
    and return them as concatenated pairs.
    """
    base_name_input = f"patient{patient}_{view_input}_{phase.upper()}"
    base_name_target = f"patient{patient}_{view_target}_{phase.upper()}"

    input_dir = os.path.join(OUTPUT_PATH, phase, view_input, f"patient{patient}")
    target_dir = os.path.join(OUTPUT_PATH, phase, view_target, f"patient{patient}")

    input_original_path = os.path.join(input_dir, f"{base_name_input}_original.png")
    input_ground_path   = os.path.join(input_dir, f"{base_name_input}_ground.png")
    target_original_path = os.path.join(target_dir, f"{base_name_target}_original.png")
    target_ground_path   = os.path.join(target_dir, f"{base_name_target}_ground.png")

    input_image = load_image(input_original_path)
    input_mask  = load_image(input_ground_path)
    target_image = load_image(target_original_path)
    target_mask  = load_image(target_ground_path)

    # Concatenate to form 2-channel inputs for condition and target respectively
    condition = tf.concat([input_image, input_mask], axis=-1)  # (256,256,2)
    target    = tf.concat([target_image, target_mask], axis=-1)  # (256,256,2)
    return condition, target

# --------------------------------------------------------------------- #

def generate_synthetic(patient, phase="ed"):
    """
    Given a patient ID and phase, load the 2CH pair (original and ground),
    pass it through the generator to produce a synthetic 4CH pair,
    and return the synthetic 4CH image and segmentation mask.
    """
    # Load the condition (2CH pair) for the given patient
    condition, _ = load_pair(phase, patient, view_input='2CH', view_target='4CH')
    condition = tf.expand_dims(condition, 0)  # Add batch dimension
    synthetic = generator(condition, training=False)  # Shape: (1,256,256,2)

    # Extract the channels: first = synthetic 4CH image, second = segmentation mask
    synthetic_image = synthetic[0, :, :, 0:1]
    synthetic_mask  = synthetic[0, :, :, 1:2]

    # Rescale from [-1,1] to [0,255]
    synthetic_image = ((synthetic_image + 1) * 127.5)
    synthetic_mask  = ((synthetic_mask + 1) * 127.5)

    return synthetic_image, synthetic_mask

# Example: Generate synthetic 4CH pair for patient "0001" in phase "ed"
synthetic_img, synthetic_msk = generate_synthetic("0500", phase="ed")
synthetic_img_np = synthetic_img.numpy().astype(np.uint8)
synthetic_msk_np = synthetic_msk.numpy().astype(np.uint8)

# Define output directory for synthetic results
synth_output_dir = os.path.join(OUTPUT_PATH, "ed", "4CH", "patient0500")
os.makedirs(synth_output_dir, exist_ok=True)

# Save synthetic images
cv2.imwrite(os.path.join(synth_output_dir, "patient0500_4CH_ed_synthetic_original.png"), synthetic_img_np)
# cv2.imwrite(os.path.join(synth_output_dir, "patient0500_4CH_ed_synthetic_ground.png"), synthetic_msk_np)

print("✅ Inference complete, synthetic images generated and saved.")
# Out:
# ✅ Inference complete, synthetic images generated and saved.

# %%
# prompt: connect the drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import cv2
import tensorflow as tf
import numpy as np

# Load the models (only generator is used in this snippet)
generator = tf.keras.models.load_model("/content/drive/MyDrive/CAMUS_GAN_Processed/generator_ed_LATEST300.h5", compile=False)

# Path where the original images are stored
OUTPUT_PATH = "/content/drive/MyDrive/CAMUS_GAN_Processed"

IMG_HEIGHT, IMG_WIDTH = 256, 256

def load_image(path):
    image = tf.io.read_file(path)
    image = tf.image.decode_png(image, channels=1)
    image = tf.cast(image, tf.float32)
    image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH])
    image = (image / 127.5) - 1  # Scale from [0,255] to [-1,1]
    return image

def load_pair(phase, patient, view_input='2CH', view_target='4CH'):
    """
    For a given phase (e.g., "ed" or "es") and patient (e.g., "0001"),
    load the 2CH images (original and ground) and 4CH images (original and ground)
    and return them as concatenated pairs.
    """
    base_name_input = f"patient{patient}_{view_input}_{phase.upper()}"
    base_name_target = f"patient{patient}_{view_target}_{phase.upper()}"

    input_dir = os.path.join(OUTPUT_PATH, phase, view_input, f"patient{patient}")
    target_dir = os.path.join(OUTPUT_PATH, phase, view_target, f"patient{patient}")

    input_original_path = os.path.join(input_dir, f"{base_name_input}_original.png")
    input_ground_path   = os.path.join(input_dir, f"{base_name_input}_ground.png")
    target_original_path = os.path.join(target_dir, f"{base_name_target}_original.png")
    target_ground_path   = os.path.join(target_dir, f"{base_name_target}_ground.png")

    input_image = load_image(input_original_path)
    input_mask  = load_image(input_ground_path)
    target_image = load_image(target_original_path)
    target_mask  = load_image(target_ground_path)

    # Concatenate to form 2-channel inputs for condition and target respectively
    condition = tf.concat([input_image, input_mask], axis=-1)  # (256,256,2)
    target    = tf.concat([target_image, target_mask], axis=-1)  # (256,256,2)
    return condition, target

def generate_synthetic(patient, phase="ed"):
    """
    Given a patient ID and phase, load the 2CH pair (original and ground),
    pass it through the generator to produce a synthetic 4CH image (and segmentation mask),
    and return the synthetic 4CH image.
    """
    # Load the condition (2CH pair) for the given patient
    condition, _ = load_pair(phase, patient, view_input='2CH', view_target='4CH')
    condition = tf.expand_dims(condition, 0)  # Add batch dimension
    synthetic = generator(condition, training=False)  # Shape: (1,256,256,2)

    # Extract the synthetic 4CH image (first channel)
    synthetic_image = synthetic[0, :, :, 0:1]
    # Rescale from [-1,1] to [0,255]
    synthetic_image = ((synthetic_image + 1) * 127.5)
    return synthetic_image

# Define output directory for synthetic images
eval_fake_dir = "/content/drive/MyDrive/eval/fake"
os.makedirs(eval_fake_dir, exist_ok=True)

# Process patients from 400 to 450
for patient_id in range(400, 451):
    # Format patient number as a 4-digit string (e.g., "0400")
    patient_str = f"{patient_id:04d}"

    # Generate synthetic image for the given patient and phase "ed"
    synthetic_img = generate_synthetic(patient_str, phase="ed")
    synthetic_img_np = synthetic_img.numpy().astype(np.uint8)

    # Define the output file path
    fake_path = os.path.join(eval_fake_dir, f"patient{patient_str}_fake.png")

    # Save the synthetic image
    cv2.imwrite(fake_path, synthetic_img_np)
    print(f"✅ Saved synthetic image for patient {patient_str}")

print("✅ Inference complete, synthetic images saved.")
# Out:
# ✅ Saved synthetic image for patient 0400
# ✅ Saved synthetic image for patient 0401
# ✅ Saved synthetic image for patient 0402
# ✅ Saved synthetic image for patient 0403
# ✅ Saved synthetic image for patient 0404
# ✅ Saved synthetic image for patient 0405
# ✅ Saved synthetic image for patient 0406
# ✅ Saved synthetic image for patient 0407
# ✅ Saved synthetic image for patient 0408
# ✅ Saved synthetic image for patient 0409
# ✅ Saved synthetic image for patient 0410
# ✅ Saved synthetic image for patient 0411
# ✅ Saved synthetic image for patient 0412
# ✅ Saved synthetic image for patient 0413
# ✅ Saved synthetic image for patient 0414
# ✅ Saved synthetic image for patient 0415
# ✅ Saved synthetic image for patient 0416
# ✅ Saved synthetic image for patient 0417
# ✅ Saved synthetic image for patient 0418
# ✅ Saved synthetic image for patient 0419
# ✅ Saved synthetic image for patient 0420
# ✅ Saved synthetic image for patient 0421
# ✅ Saved synthetic image for patient 0422
# ✅ Saved synthetic image for patient 0423
# ✅ Saved synthetic image for patient 0424
# ✅ Saved synthetic image for patient 0425
# ✅ Saved synthetic image for patient 0426
# ✅ Saved synthetic image for patient 0427
# ✅ Saved synthetic image for patient 0428
# ✅ Saved synthetic image for patient 0429
# ✅ Saved synthetic image for patient 0430
# ✅ Saved synthetic image for patient 0431
# ✅ Saved synthetic image for patient 0432
# ✅ Saved synthetic image for patient 0433
# ✅ Saved synthetic image for patient 0434
# ✅ Saved synthetic image for patient 0435
# ✅ Saved synthetic image for patient 0436
# ✅ Saved synthetic image for patient 0437
# ✅ Saved synthetic image for patient 0438
# ✅ Saved synthetic image for patient 0439
# ✅ Saved synthetic image for patient 0440
# ✅ Saved synthetic image for patient 0441
# ✅ Saved synthetic image for patient 0442
# ✅ Saved synthetic image for patient 0443
# ✅ Saved synthetic image for patient 0444
# ✅ Saved synthetic image for patient 0445
# ✅ Saved synthetic image for patient 0446
# ✅ Saved synthetic image for patient 0447
# ✅ Saved synthetic image for patient 0448
# ✅ Saved synthetic image for patient 0449
# ✅ Saved synthetic image for patient 0450
# ✅ Inference complete, synthetic images saved.

# %%
import os
import shutil

# Base source folder where patient subfolders are located.
source_base = "/content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH"
# Destination folder where the renamed images will be stored.
destination_folder = "/content/drive/MyDrive/eval/actual"

# Create the destination folder if it doesn't exist.
os.makedirs(destination_folder, exist_ok=True)

# Loop through the patient IDs 400 to 450 (inclusive).
for i in range(400, 451):
    # Define the patient subfolder (e.g., patient0400).
    patient_folder = os.path.join(source_base, f"patient{i:04d}")
    # Define the source image file name within each patient folder.
    src_filename = f"patient{i:04d}_4CH_ED_original.png"
    src_path = os.path.join(patient_folder, src_filename)

    # Define the destination file name.
    dst_filename = f"patient{i:04d}_actual.png"
    dst_path = os.path.join(destination_folder, dst_filename)

    # Check if the source file exists and then copy it.
    if os.path.exists(src_path):
        shutil.copy(src_path, dst_path)
        print(f"Copied {src_path} to {dst_path}")
    else:
        print(f"Source file not found: {src_path}")
# Out:
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0400/patient0400_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0400_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0401/patient0401_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0401_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0402/patient0402_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0402_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0403/patient0403_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0403_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0404/patient0404_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0404_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0405/patient0405_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0405_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0406/patient0406_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0406_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0407/patient0407_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0407_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0408/patient0408_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0408_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0409/patient0409_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0409_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0410/patient0410_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0410_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0411/patient0411_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0411_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0412/patient0412_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0412_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0413/patient0413_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0413_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0414/patient0414_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0414_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0415/patient0415_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0415_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0416/patient0416_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0416_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0417/patient0417_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0417_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0418/patient0418_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0418_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0419/patient0419_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0419_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0420/patient0420_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0420_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0421/patient0421_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0421_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0422/patient0422_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0422_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0423/patient0423_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0423_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0424/patient0424_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0424_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0425/patient0425_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0425_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0426/patient0426_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0426_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0427/patient0427_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0427_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0428/patient0428_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0428_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0429/patient0429_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0429_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0430/patient0430_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0430_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0431/patient0431_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0431_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0432/patient0432_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0432_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0433/patient0433_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0433_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0434/patient0434_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0434_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0435/patient0435_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0435_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0436/patient0436_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0436_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0437/patient0437_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0437_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0438/patient0438_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0438_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0439/patient0439_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0439_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0440/patient0440_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0440_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0441/patient0441_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0441_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0442/patient0442_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0442_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0443/patient0443_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0443_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0444/patient0444_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0444_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0445/patient0445_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0445_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0446/patient0446_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0446_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0447/patient0447_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0447_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0448/patient0448_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0448_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0449/patient0449_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0449_actual.png
# Copied /content/drive/MyDrive/CAMUS_GAN_Processed/ed/4CH/patient0450/patient0450_4CH_ED_original.png to /content/drive/MyDrive/eval/actual/patient0450_actual.png
